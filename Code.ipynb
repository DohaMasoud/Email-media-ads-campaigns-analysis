# %%
import requests
import pandas as pd
import io

api_key = "12dbc5f0"

url_campaigns = f"https://my.api.mockaroo.com/email_campaigns_2024.json?key={api_key}"
url_performance = f"https://my.api.mockaroo.com/email_campaign_data_performance.json?key={api_key}"

response_campaigns = requests.get(url_campaigns)
response_performance = requests.get(url_performance)

if response_campaigns.status_code == 200 and response_performance.status_code == 200:
    try:
        df_campaigns = pd.read_csv(io.StringIO(response_campaigns.text))
        df_performance = pd.read_csv(io.StringIO(response_performance.text))

        print("DataFrames created successfully!")

    except Exception as e:
        print(" Failed to parse CSV:", e)
else:
    print("Request failed.")
# Out:
# DataFrames created successfully!

# %%
df_campaigns
# Out:
#   campaign_id\t              Compaign_name age_group platform start_date  \
# 0  CAMPAIGN_021  New Arrival: Try It First     25-34  Klaviyo  6/23/2024
# 1  CAMPAIGN_022           Fresh Drop Alert       55+  Klaviyo  12/8/2024
# 2  CAMPAIGN_023            Don't Miss Out!     45-54  Klaviyo  1/16/2024
#
#    end_date   objectives  Budget
# 0  8/8/2024      Traffic   12555
# 1  3/1/2025      Traffic    2794
# 2  3/2/2024  Conversions    3026

# %%
df_performance.head()
# Out:
#                             customer id                name  \
# 0  8d616cc7-b558-48a1-9c38-07447bd56713   Jaimie Collingdon
# 1  327e1c6d-07d7-4763-8de3-00e7b70a04a3  Prudence Dobrowski
# 2  1785da7f-d88d-4655-984f-4f456d60bd30  Darrelle Ochiltree
# 3  3c75eb54-65f0-4d05-9f41-b42ccb3570b2     Kingsly Esselin
# 4  d1200ff9-2072-4158-9d61-2e94b4fb52f7      Sterne Daybell
#
#                      email customer_status response_type   send_date  \
# 0     jcollingdon0@wsj.com      Interested   No Response   1/21/2025
# 1      pdobrowski1@cnn.com      Interested   No Response  11/15/2024
# 2    dochiltree2@europa.eu      Interested   No Response   4/24/2024
# 3      kesselin3@sogou.com      Interested        Booked   2/16/2024
# 4  sdaybell4@rakuten.co.jp      Interested        Booked    9/5/2024
#
#     open_date bounce_date  subscriptions  conversions click_date  \
# 0  12/25/2024   6/15/2024              4            2  2/17/2024
# 1   3/12/2024         NaN              0            0  10/6/2024
# 2   8/27/2024         NaN              3            1   2/9/2024
# 3   12/7/2024  11/15/2024              4            3   3/7/2024
# 4    4/3/2024   5/30/2024              3            2   4/7/2024
#
#    spam_reports revenue_generated campaign_id\t
# 0             2               Sol  CAMPAIGN_022
# 1             2            Dollar  CAMPAIGN_022
# 2             0            Rupiah  CAMPAIGN_022
# 3             0              Real  CAMPAIGN_022
# 4             2              Euro  CAMPAIGN_022

# %%
from sqlalchemy import create_engine
import urllib

# %%
#!pip install pandas sqlalchemy pyodbc
